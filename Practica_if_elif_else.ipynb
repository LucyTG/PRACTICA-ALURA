# %%
manzanas_vendidas = int(input("Digite la cantidad de manzanas vendidas: "))
print(f"Manzanas vendidas: {manzanas_vendidas}")
platanos_vendidos = int(input(f"Digite la cantidad de Platanos vendidos: "))
print(f"Platanos vendidos: {platanos_vendidos}")
if manzanas_vendidas > platanos_vendidos:
    print("las manzanas tuvieron mas ventas")
elif platanos_vendidos > manzanas_vendidas:
    print("los platanos tuvieron mas ventas")
else:
    print("las ventas fueron iguales")
# Out:
# Manzanas vendidas: 5
# Platanos vendidos: 8
# los platanos tuvieron mas ventas

# %%
temperatura = float(input("ingrese la temperatura en grados celsius: "))
print(f"Temperatura ingresada: {temperatura}°C")
if temperatura > 25:
    print("Alerta, la temperatura supera los 25°C")
else:
    print("La temperatura es adecuada")
# Out:
# Temperatura ingresada: 23.0°C
# La temperatura es adecuada

# %%
informe_A = int(input("Ingrese los dias necesarios para el informe A: "))
informe_B = int(input("Ingrese los dias necesarios para el informe B: "))
informe_C = int(input("Ingrese los dias necesarios para el informe C: "))
print(f"Días para informe A: {informe_A}, informe B: {informe_B}, informe C: {informe_C}")
if informe_A < 0 or informe_B < 0 or informe_C < 0:
    print("Error: Los días ingresados no pueden ser negativos.")
else:
    suma = informe_A + informe_B + informe_C
    print(f"El total de días necesarios para completar los informes es: {suma} días.")
# Out:
# Días para informe A: 4, informe B: -8, informe C: 8
# Error: Los días ingresados no pueden ser negativos.

# %%
peso = float(input("Ingrese su peso en kilogramos: "))
altura = float(input("Ingrese su altura en metros: "))
imc = peso / (altura ** 2)
print(f"Su índice de masa corporal (IMC) es: {imc}")
if imc < 18.5:
    print("Categoría: Bajo peso")
elif 18.5 <= imc < 25:
    print("Categoría: Peso normal")
else:
    print("Categoría: Sobrepeso")
# Out:
# Su índice de masa corporal (IMC) es: 22.367440024560327
# Categoría: Peso normal

# %%
ingreso_mensual = float(input("Ingrese su ingreso mensual en dólares: "))
hijos = int(input("Ingrese el número de hijos que tiene: "))

if ingreso_mensual <= 2000 and hijos >= 1:
    print("Usted es elegible para recibir asistencia social.")
elif ingreso_mensual > 2000 and hijos < 1:
    print(f"No es elegible porque su ingreso supera el límite de 2000 dólares, ${ingreso_mensual} y no tiene hijos.")
elif ingreso_mensual > 2000:
    print(f"No es elegible porque su ingreso supera el límite permitido. ${ingreso_mensual}")
elif hijos < 1:
    print(f"No es elegible porque no tiene hijos. Total de hijos ingresados: {hijos}")
else:
    print("No es elegible para recibir asistencia social.")
# Out:
# Usted es elegible para recibir asistencia social.

# %%
puntuacion = int(input("Ingrese la puntuación de desempeño de (0 a 10): "))
años_experiencia = int(input("Ingrese los años de experiencia: "))
if puntuacion >= 7 and años_experiencia >= 5:
    print("Elegible para ascenso")
elif puntuacion >= 7 and años_experiencia < 5:
    print("Buen desempeño, sigue así")
elif puntuacion < 7:
    print("Necesita mejorar su desempeño")
else:
    print("Datos inválidos")
# Out:
# Elegible para ascenso

# %%
numero = int(input("Ingrese un número entero para iniciar el juego: "))
if numero % 3 == 0 and numero % 5 == 0:
    print("El número es magico")
elif numero % 3 == 0:
    print("El número es divisible por 3")
elif numero % 5 == 0:
    print("El número es divisible por 5")
else:
    print("El número no es magico")
# Out:
# El número es magico

# %%
ingreso_familiar = float(input("Ingrese el ingreso familiar mensual: "))
promedio_estudiante = float(input("Ingrese el promedio académico del estudiante: "))
asistencia = float(input("Ingrese el porcentaje de asistencia del estudiante: "))
if ingreso_familiar <1500 and promedio_estudiante > 8.0 and asistencia >= 90:
    print("Beca completa")
elif ingreso_familiar < 2500 and promedio_estudiante >= 7.0 and asistencia >= 80:
    print("Media beca")
else:
    print("No es elegible para beca")
# Out:
# Media beca

# %%
edad = int(input("Ingrese su edad: "))
distancia = float(input("Ingrese la distancia en kilómetros que recorre diariamente: "))
if edad < 6:
    print("Viaje gratis")
elif 6 <= edad <= 18 and distancia <= 20:
    print("Valor del pasaje $1.50")
elif 6 <= edad <= 18 and distancia > 20:
    print("Valor del pasaje $2.50")
elif edad > 18 and distancia <= 20:
    print("Valor del pasaje $2.50")
else:
    print("Valor del pasaje $4.00")
# Out:
# Valor del pasaje $2.50

# %%
ingresos_Totales = float(input("Por favor digite los ingresos tolales: $"))
gastos_Totales = float(input("Por favor digite los gastos totales: $"))
new_cliente = int(input("Por faor ingrese el numero de empleados nuevos: "))
if (ingresos_Totales - gastos_Totales > 10000) and new_cliente > 50:
    print ("Trimestre excelente")
elif (ingresos_Totales - gastos_Totales > 5000) and new_cliente >= 20:
    print("Trimestre bueno")
elif (ingresos_Totales - gastos_Totales > 0):
    print("Trimestre regular")
elif (ingresos_Totales - gastos_Totales <= 0):
    print("Trimestre malo")
else:
    print("Ninguna de las anteriores jj")
# Out:
# Trimestre regular
